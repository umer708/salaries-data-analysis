# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy as sp
import joblib as jb

df = pd.read_csv('C:/Users/Umar Goraya/Downloads/Salary_Data (1).csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
import pandas as pd

file_path = r"C:\Users\Umar Goraya\Downloads\Salary_Data (1).csv"
data = pd.read_csv(file_path)
print=(data.head())

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#for missing values
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data['Salary'], kde=True)
plt.show()
# Out:
# c:\Users\Umar Goraya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#relationship
sns.scatterplot(x='YearsExperience', y='Salary', data=data)
plt.show()

# %%
sns.boxplot(data['Salary'])
plt.show()

# %%
data = data.drop_duplicates()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
plt.scatter(data['YearsExperience'], data['Salary'], color='maroon', marker='o')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()

# %%
x = data["YearsExperience"]
y = data["Salary"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x = data[["YearsExperience"]]
y = data["Salary"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

Lr = LinearRegression()
Lr.fit(x_train, y_train)
y_pred = Lr.predict(x_test)
